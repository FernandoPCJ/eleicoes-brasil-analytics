# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Eleições Brasil Analytics iniciado!")
# Out:
# Eleições Brasil Analytics iniciado!

# %%
from pathlib import Path

BASE_DIR = Path.cwd()

DATA_RAW = BASE_DIR / "data" / "raw"
DATA_PROCESSED = BASE_DIR / "data" / "processed"

print("Projeto:", BASE_DIR)
print("Dados brutos:", DATA_RAW)
print("Dados tratados:", DATA_PROCESSED)
# Out:
# Projeto: C:\Users\Fernando\eleicoes-brasil-analytics
# Dados brutos: C:\Users\Fernando\eleicoes-brasil-analytics\data\raw
# Dados tratados: C:\Users\Fernando\eleicoes-brasil-analytics\data\processed

# %%
from pathlib import Path
import pandas as pd

print("Ambiente pronto para análise!")
print(f"Diretório atual: {Path.cwd()}")
# Out:
# Ambiente pronto para análise!
# Diretório atual: C:\Users\Fernando\eleicoes-brasil-analytics

# %%
from pathlib import Path


BASE_DIR = Path.cwd()

RAW_DATA = BASE_DIR / "data" / "raw"

PROCESSED_DATA = BASE_DIR / "data" / "processed"


print(BASE_DIR)
print(RAW_DATA)
print(PROCESSED_DATA)
# Out:
# C:\Users\Fernando\eleicoes-brasil-analytics
# C:\Users\Fernando\eleicoes-brasil-analytics\data\raw
# C:\Users\Fernando\eleicoes-brasil-analytics\data\processed
